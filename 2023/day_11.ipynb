# %%
test = """
...#......
.......#..
#.........
..........
......#...
.#........
.........#
..........
.......#..
#...#.....
"""

# data = [line for line in test.strip().splitlines()]

file_path = 'day_11_input.txt'
with open(file_path, 'r') as file:
    data = [line.strip() for line in file]

def is_empty(data_list):
    return len(set(data_list)) == 1

def column(data, index):
    return (row[index] for row in data)

def insert_column(grid, index, new_column):
    for i in range(len(grid)):
        grid[i] = grid[i][:index] + new_column + grid[i][index:]
    
empty_rows = [i for i, row in enumerate(data) if is_empty(row)]
empty_columns = [i for i in range(len(data[0])) if is_empty(column(data, i))]

for i, row_index in enumerate(empty_rows):
    index = row_index + i
    data.insert(index, data[index])

for i, row_index in enumerate(empty_columns):
    index = row_index + i
    insert_column(data, index, '.')

def get_galaxy_coords(data):
    coords = []
    for y, row in enumerate(data):
        for x, element in enumerate(row):
            if element == '#':
                coords.append((x, y))
    return coords

def manhattan_distance(point1, point2):
    return abs(point1[0] - point2[0]) + abs(point1[1] - point2[1])

def distances_between_points(coordinates):
    distances = []
    n = len(coordinates)

    for i in range(n - 1):
        for j in range(i + 1, n):
            distance = manhattan_distance(coordinates[i], coordinates[j])
            distances.append(distance)

    return distances

coords = get_galaxy_coords(data)
distances = distances_between_points(coords)
sum(distances)
# Out:
# 10490062

# %%
test = """
...#......
.......#..
#.........
..........
......#...
.#........
.........#
..........
.......#..
#...#.....
"""

def get_galaxy_coords(data):
    coords = []
    for y, row in enumerate(data):
        for x, element in enumerate(row):
            if element == '#':
                coords.append((x, y))
    return coords

def is_empty(data_list):
    return len(set(data_list)) == 1

def column(data, index):
    return (row[index] for row in data)

def count_numbers_bigger_than(num, ordered_list):
    count = 0
    for i in ordered_list:
        if num > i:
            count += 1
        elif num == i:
            raise # should never get here
        else:
            break  # Stops counting as soon as the number in the list is not bigger
    return count

def manhattan_distance(point1, point2):
    return abs(point1[0] - point2[0]) + abs(point1[1] - point2[1])

def distances_between_points(coordinates):
    distances = []
    n = len(coordinates)

    for i in range(n - 1):
        for j in range(i + 1, n):
            distance = manhattan_distance(coordinates[i], coordinates[j])
            distances.append(distance)

    return distances

def stretch(x, y, empty_rows, empty_columns):
    factor = 1_000_000
    adjusted_factor = factor - 1
    x_multiple = count_numbers_bigger_than(x, empty_columns)
    y_multiple = count_numbers_bigger_than(y, empty_rows)

    x_new = x + (x_multiple * adjusted_factor)
    y_new = y + (y_multiple * adjusted_factor)
    return x_new, y_new


# data = [line for line in test.strip().splitlines()]

file_path = 'day_11_input.txt'
with open(file_path, 'r') as file:
    data = [line.strip() for line in file]


coords = get_galaxy_coords(data)
empty_rows = [i for i, row in enumerate(data) if is_empty(row)]
empty_columns = [i for i in range(len(data[0])) if is_empty(column(data, i))]
stretched_coords = [stretch(x, y, empty_rows, empty_columns) for x, y in coords]

sum(distances_between_points(stretched_coords))
# Out:
# 382979724122
